# %%
# !git clone https://github.com/saadullah-cs/defect-detection-pipeline.git
# %cd defect-detection-pipeline

# !pip install -r requirements.txt
# Out:
# Cloning into 'defect-detection-pipeline'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 33 (delta 9), reused 30 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 19.03 KiB | 19.03 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/defect-detection-pipeline
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 92.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 73.1 MB/s eta 0:00:00
# ...

# %%
import os

os.environ['KAGGLE_API_TOKEN'] = "KGAT_1502d1ecd44fa30e66d57db154beeea1"

print("Kaggle API successfully configured.")
# Out:
# Kaggle API successfully configured.

# %%
# !pip install --upgrade kaggle -q

# !kaggle datasets download -d kaustubhdikshit/neu-surface-defect-database

# !mkdir -p data/raw

# Extraction
# !unzip -q neu-surface-defect-database.zip -d data/raw/

# Moving everything out of NEU-DET and into data/raw/
# !mv data/raw/NEU-DET/* data/raw/

# !rm -r data/raw/NEU-DET/

# Verification of directory structure
# !ls -l data/raw/
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.5/262.5 kB 17.7 MB/s eta 0:00:00
# Dataset URL: https://www.kaggle.com/datasets/kaustubhdikshit/neu-surface-defect-database
# License(s): unknown
# ...
# 100% 26.4M/26.4M [00:00<00:00, 96.9MB/s]
#
# total 8
# drwxr-xr-x 4 root root 4096 Aug  8 19:44 train
# drwxr-xr-x 4 root root 4096 Aug  8 19:44 validation

# %%
# !pip install wandb -q
# !wandb login
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: saadullah (saadullah-university-of-engineering-and-technology-peshawar) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# %cd /content/defect-detection-pipeline
# !git fetch origin
# !git reset --hard origin/main
# Out:
# /content/defect-detection-pipeline
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 592 bytes | 296.00 KiB/s, done.
# From https://github.com/saadullah-cs/defect-detection-pipeline
#    bf7eed3..166a97e  main       -> origin/main
# HEAD is now at 166a97e fix: recursively scan subdirectories for NEU dataset images

# %%
# Uninstall the CPU-only PyTorch packages
# !pip uninstall -y torch torchvision torchaudio

# Reinstall PyTorch with CUDA support (matching Colab's environment)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Found existing installation: torch 2.11.0+cpu
# Uninstalling torch-2.11.0+cpu:
#   Successfully uninstalled torch-2.11.0+cpu
# Found existing installation: torchvision 0.26.0+cpu
# Uninstalling torchvision-0.26.0+cpu:
#   Successfully uninstalled torchvision-0.26.0+cpu
# Found existing installation: torchaudio 2.11.0+cpu
# Uninstalling torchaudio-2.11.0+cpu:
#   Successfully uninstalled torchaudio-2.11.0+cpu
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 92.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 73.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.6 MB/s eta 0:00:00
# ...

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA Available: True
# Device Name: Tesla T4

# %%
# !python -m scripts.train
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: saadullah (saadullah-university-of-engineering-and-technology-peshawar) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ setting up run yk1c0y5n (0.0s)
# wandb: ⣻ setting up run yk1c0y5n (0.0s)
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/defect-detection-pipeline/wandb/run-20260808_194551-yk1c0y5n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50-baseline
# wandb: ⭐️ View project at https://wandb.ai/saadullah-university-of-engineering-and-technology-peshawar/neu-surface-defect-detection
# wandb: 🚀 View run at https://wandb.ai/saadullah-university-of-engineering-and-technology-peshawar/neu-surface-defect-detection/runs/yk1c0y5n
# 2026-08-08 19:45:52,901 - INFO - Initializing training on device: cuda
# ...

# %%
# %cd /content/defect-detection-pipeline
# !git fetch origin
# !git reset --hard origin/main

# !python -m scripts.evaluate
# Out:
# /content/defect-detection-pipeline
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 549 bytes | 549.00 KiB/s, done.
# From https://github.com/saadullah-cs/defect-detection-pipeline
#    166a97e..856f207  main       -> origin/main
# HEAD is now at 856f207 refactor: sync evaluate.py with new dataset phase loader
# 2026-08-08 19:56:33,041 - INFO - Loaded 360 images from validation split.
# ...

# %%
# !kaggle datasets download -d avdvhh/mvtec-defect-detection-dataset

# !unzip -q mvtec-defect-detection-dataset.zip

# !mkdir -p /content/defect-detection-pipeline/data/mvtec/

# !mv mvtec_Defect_detection_dataset/bottle /content/defect-detection-pipeline/data/mvtec/

# !rm -rf mvtec_Defect_detection_dataset mvtec-defect-detection-dataset.zip

# !ls -l /content/defect-detection-pipeline/data/mvtec/bottle/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/avdvhh/mvtec-defect-detection-dataset
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 4.91G/4.91G [01:17<00:00, 67.8MB/s]
#
# total 40
# drwxr-xr-x 5 root root  4096 Aug  8 20:03 ground_truth
# -rw-r--r-- 1 root root 20845 Jul 31  2025 license.txt
# -rw-r--r-- 1 root root   881 Jul 31  2025 readme.txt
# drwxr-xr-x 6 root root  4096 Aug  8 20:03 test
# drwxr-xr-x 3 root root  4096 Aug  8 20:03 train

# %%
# !python -m scripts.train_anomaly
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: saadullah (saadullah-university-of-engineering-and-technology-peshawar) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.28.0
# wandb: Run data is saved locally in /content/defect-detection-pipeline/wandb/run-20260808_200502-ky0xw1qq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run autoencoder-bottle
# wandb: ⭐️ View project at https://wandb.ai/saadullah-university-of-engineering-and-technology-peshawar/neu-surface-defect-detection
# wandb: 🚀 View run at https://wandb.ai/saadullah-university-of-engineering-and-technology-peshawar/neu-surface-defect-detection/runs/ky0xw1qq
# 2026-08-08 20:05:03,523 - INFO - Initializing Autoencoder training for category: bottle
# ...

# %%
# !python -m scripts.infer_anomaly
# Out:
# 2026-08-08 20:17:40,594 - INFO - Initialized Anomaly Autoencoder with latent dimension: 128
# 2026-08-08 20:17:40,849 - INFO - Loading Autoencoder weights from /content/defect-detection-pipeline/checkpoints/best_autoencoder_bottle.pth
# 2026-08-08 20:17:40,900 - INFO - Processing test image: /content/defect-detection-pipeline/data/mvtec/bottle/test/broken_large/000.png
#
# ...
# API JSON PAYLOAD
# ...
# {
#     "defect_detected": true,
#     "defect_type": "unknown_anomaly",
#     "confidence_score": 0.26516175270080566,
#     "bounding_box_coordinates": [
#         [
#             0,
#             0,
#             900,
#             900
#         ]
#     ]
# }

# %%
# !pip install onnxscript

# !python -m scripts.export_onnx
# Out:
# ...
# 2026-08-08 20:23:10,309 - INFO - Initialized Anomaly Autoencoder with latent dimension: 128
# 2026-08-08 20:23:10,310 - INFO - Loading weights from /content/defect-detection-pipeline/checkpoints/best_autoencoder_bottle.pth
# 2026-08-08 20:23:10,332 - INFO - Tracing computational graph and exporting to ONNX...
# /content/defect-detection-pipeline/scripts/export_onnx.py:50: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# ...
